# %% [markdown]
# # Data analyses WPI and Exact Earth datasets
#
# Date: 31-01-2020 <br>
# Concept version: 1.0 <br>
# Author: Pieter Lems  <br>
#
# © Copyright 2019 Ministerie van Defensie
#
#
# ## Contents notebook
# - World Port Index
#   - Import set
#   - Show row
#   - Show columns
#   - Create table
#   - Visualize
# - Exact Earth month 2017-09
#   - Import set
#   - Show row
#   - Show columns
#   - Create table
#   - Visualize
#
#
#
# ## Datasets in notebook. ("../Data/MV_EE_WPI_SHP/")
# - World Port Index dataset : ../Data/MV_EE_WPI_SHP/World_Ports_Index/WPI.shp
# - Exact Earth dataset: ../Data/MV_EE_WPI_SHP/Exact_Earth/density_20170901_to_20170930_customgrid_aoi.shp

# %% [markdown]
# ---
# ## Import required modules
# ---

# %%
import geopandas as gpd
import pandas as pd
import cartopy
import cartopy.crs as ccrs 
import cartopy.feature as cfeature 
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Define generic functions

# %% [markdown]
# ### Function: init_cartopymap():
# This function creates a new cartopyMap and then returns the map instance

# %%
def init_cartopymap():
    
    plt.figure(figsize = (20, 12))
    
    m = plt.axes(projection=ccrs.PlateCarree())

    m.coastlines(resolution='10m')
    
    m.add_feature(cartopy.feature.LAND.with_scale('10m'), edgecolor='black', facecolor = "white")
    
    m.add_feature(cfeature.OCEAN)
    
    m.add_feature(cfeature.LAKES.with_scale('10m'), edgecolor = 'black')
    
    m.add_feature(cfeature.RIVERS.with_scale('10m')) 
    
    m.add_feature(cfeature.BORDERS.with_scale('10m'))

    return m

# %% [markdown]
# ---
# ### Function: dfs_on_cartopymap():
# This function creates a map and visualizes the inserted dataframes on a CartopyMap
#
# - parameter 1: A list of dataframes, this can also be a list of just one dataframe
# - parameter 2: The longitude column in the dataframe
# - parameter 3: The latitude column in the dataframe
# - parameter 4: The color of the datapoints
# - parameter 5: The size of the datapoints

# %%
def dfs_on_cartopymap(dfList,lonColumn,latColumn,color,size):

    m = init_cartopymap()
    
    for df in dfList: 
        
        m.scatter(df[lonColumn], 
                  df[latColumn],
                  color=color, 
                  s = size)    
    return m

# %% [markdown]
# ---
# # World Port Index
# Web Map of the World Port Index Twenty Fifth Edition (2016). This web map presents the location, characteristics, known facilities, and available services of ports, shipping facilities and oil terminals throughout the world.
#
# Several layers have been developed to indicate the locations of the world's ports by harbour type and whether or not they include an oil terminal.
#
# The uploaded version of the World Ports Index includes enriched information combining the information found throughout all the released information from the National Geospatial Intelligence Agency.
#
# Some info about the data set:
# - 3369 rows
# - 79 columns

# %% [markdown]
# #### Read the SHP dataset using GeoPandas

# %%
World_Port_Index = gpd.read_file("../Data/World_Port_Index/WPI.shp")

# %% [markdown]
# #### Show first row of dataframe.

# %%
World_Port_Index[:1]
# Out:
#    INDEX_NO  REGION_NO PORT_NAME COUNTRY   LATITUDE   LONGITUDE  LAT_DEG  \
# 0   61090.0    61070.0  SHAKOTAN      RU  43.866667  146.833333     43.0
#
#    LAT_MIN LAT_HEMI  LONG_DEG  ...  PROVISIONS WATER FUEL_OIL DIESEL  \
# 0     52.0        N     146.0  ...        None  None     None   None
#
#   DECKSUPPLY ENG_SUPPLY REPAIRCODE DRYDOCK RAILWAY                    geometry
# 0       None       None       None    None    None  POINT (146.83333 43.86667)
#
# [1 rows x 79 columns]

# %% [markdown]
# #### Print columnames and their datatypes.

# %%
display(World_Port_Index)
# Out:
#       INDEX_NO  REGION_NO              PORT_NAME COUNTRY   LATITUDE  \
# 0      61090.0    61070.0               SHAKOTAN      RU  43.866667
# 1      61110.0    61100.0            MOMBETSU KO      JP  44.350000
# 2      61120.0    61100.0            ABASHIRI KO      JP  44.016667
# 3      61130.0    61100.0              NEMURO KO      JP  43.333333
# 4      61140.0    61100.0            HANASAKI KO      JP  43.283333
# ...        ...        ...                    ...     ...        ...
# 3664   60205.0    59850.0          SUIZHANG GANG      CN  40.066667
# 3665   44790.0    44360.0                 BODRUM      TR  37.033333
# 3666   47110.0    47090.0                   LAMU      KE  -2.266667
# 3667   60376.0    60315.0         GWANGYANG HANG      KR  34.850000
# 3668   61245.0    61100.0  ISHIKARI BAY NEW PORT      JP  43.216667
#
#        LONGITUDE  LAT_DEG  LAT_MIN LAT_HEMI  LONG_DEG  ...  PROVISIONS WATER  \
# 0     146.833333     43.0     52.0        N     146.0  ...        None  None
# 1     143.350000     44.0     21.0        N     143.0  ...        None     Y
# 2     144.283333     44.0      1.0        N     144.0  ...        None     Y
# 3     145.583333     43.0     20.0        N     145.0  ...           Y     Y
# 4     145.583333     43.0     17.0        N     145.0  ...        None     Y
# ...          ...      ...      ...      ...       ...  ...         ...   ...
# 3664  121.050000     40.0      4.0        N     121.0  ...        None  None
# 3665   27.433333     37.0      2.0        N      27.0  ...        None     Y
# 3666   40.900000      2.0     16.0        S      40.0  ...        None     Y
# 3667  127.800000     34.0     51.0        N     127.0  ...           Y     Y
# 3668  141.283333     43.0     13.0        N     141.0  ...        None     Y
#
#      FUEL_OIL DIESEL DECKSUPPLY ENG_SUPPLY REPAIRCODE DRYDOCK RAILWAY  \
# 0        None   None       None       None       None    None    None
# 1        None      Y       None       None          C    None    None
# 2        None      Y       None       None          C    None    None
# 3           Y   None       None       None       None    None    None
# 4           Y   None       None       None       None    None    None
# ...       ...    ...        ...        ...        ...     ...     ...
# 3664     None   None       None       None       None    None    None
# 3665        Y      Y       None       None          C    None    None
# 3666     None   None       None       None          N    None    None
# 3667        Y      Y       None       None          B       M    None
# 3668     None   None       None       None       None    None    None
#
#                         geometry
# 0     POINT (146.83333 43.86667)
# 1     POINT (143.35000 44.35000)
# 2     POINT (144.28333 44.01667)
# 3     POINT (145.58333 43.33333)
# 4     POINT (145.58333 43.28333)
# ...                          ...
# 3664  POINT (121.05000 40.06667)
# 3665   POINT (27.43333 37.03333)
# 3666   POINT (40.90000 -2.26667)
# 3667  POINT (127.80000 34.85000)
# 3668  POINT (141.28333 43.21667)
#
# [3669 rows x 79 columns]

# %% [markdown]
# #### Create a table and put the values, obtained from the line above, in that table.

# %% [markdown]
# #### Columns with their data types(79):
#
#
# |Column|Type|---|Column|Type|---|Column|Type|---|Column|Type|
# |--|--|--|--|--|--|--|--|--|--|--|
# |INDEX_NO |float64 |---|PORTOFENTR  |    string|---|GARBAGE      |   string|
# |REGION_NO   |   float64 |---|TIDE_RANGE |    float64|---|DEGAUSS       |  string|
# |PORT_NAME   |    string |---|HOLDGROUND  |    string|---|DRTYBALLST     | string|
# |COUNTRY      |     string |---|TURN_BASIN  |    string|---|CRANEFIXED     | string|
# |LATITUDE    |    float64 |---|US_REP      |    string|---|CRANEMOBIL    |  string|
# |LONGITUDE   |     float64|---|ETAMESSAGE  |    string|---|CRANEFLOAT |     string|
# |LAT_DEG     |   float64|---|PILOT_REQD  |    string|---|LIFT_100_|       string|
# |LAT_MIN     |   float64|---|PILOTAVAIL  |    string|---|LIFT50_100|      string|
# |LAT_HEMI   |     string|---|LOC_ASSIST  |    string|---|LIFT_25_49 |     string|
# |LONG_DEG   |    float64|---|PILOTADVSD  |    string|---|LIFT_0_24  |     string|
# |LONG_MIN   |    float64|---|TUGSALVAGE  |    string|---|LONGSHORE   |    string|
# |LONG_HEMI  |     string|---|TUG_ASSIST  |    string|---|ELECTRICAL  |    string|
# |PUB        |     string|---|PRATIQUE    |    string|---|SERV_STEAM  |    string|
# |CHART       |    string|---|SSCC_CERT    |   string|---|NAV_EQUIP   |    string|
# |HARBORSIZE  |    string|---|QUAR_OTHER   |   string|---|ELECREPAIR  |    string|
# |HARBORTYPE  |   string|---|COMM_PHONE   |   string|---|PROVISIONS  |    string|
# |SHELTER     |    string|---|COMM_FAX     |  string|---|WATER       |    string|
# |ENTRY_TIDE   |   string|---|COMM_RADIO   |   string|---|FUEL_OIL    |    string|
# |ENTRYSWELL  |    string|---|COMM_VHF     |   string|---|DIESEL      |    string|
# |ENTRY_ICE   |    string|---|COMM_AIR    |    string|---|DECKSUPPLY  |    string|
# |ENTRYOTHER  |    string|---|COMM_RAIL   |    string|---|ENG_SUPPLY  |    string|
# |OVERHD_LIM  |    string|---|CARGOWHARF  |    string|---|REPAIRCODE  |    string|
# |CHAN_DEPTH  |    string|---|CARGO_ANCH  |    string|---|DRYDOCK     |    string|
# |ANCH_DEPTH  |    string|---|CARGMDMOOR   |   string|---|RAILWAY     |    string|
# |CARGODEPTH  |    string|---|CARBCHMOOR   |   string|---|geometry    |  geometry|
# |OIL_DEPTH   |    string|---|MED_FACIL    |   string|---

# %% [markdown]
# #### Create a plot MatplotLib on CartopyMap.

# %%
dfs_on_cartopymap([World_Port_Index],'LONGITUDE','LATITUDE',"red",20)

# %% [markdown]
# ---
#
# # Exact Earth
# exactEarth Ltd is a publicly traded data services company delivering real-time global location-based maritime vessel tracking information utilizing patented Satellite AIS detection technology.
#
# exactEarth provides Satellite AIS data services to commercial markets as well as government customers in India, Canada, US, Australia and across Europe.
#
#
# Some info about the data set:
# - 1787801 rows
# - 10 columns

# %% [markdown]
# #### Read the SHP dataset using GeoPandas

# %%
Exact_Earth = gpd.read_file("../Data/MV_EE_WPI_SHP/Exact_Earth/density_20170901_to_20170930_customgrid_aoi.shp")

# %% [markdown]
# #### Show first row of dataframe.

# %%
Exact_Earth[:1]
# Out:
#    COUNT  FISHING  PASSENGER  CARGO  TANKER  OTHER  SOG_mean    COG_mean   COG_var                                           geometry
# 0      8        0          0      5       2      1    1.1375  272.719838  0.552594  POLYGON ((2.04000 52.99000, 2.05000 52.99000, ...

# %% [markdown]
# #### Print columns and their datatypes

# %%
display(Exact_Earth)
# Out:
# COUNT           int64
# FISHING         int64
# PASSENGER       int64
# CARGO           int64
# TANKER          int64
# OTHER           int64
# SOG_mean      float64
# COG_mean      float64
# COG_var       float64
# geometry     geometry
# dtype: object

# %% [markdown]
# |Column|Type|desc|
# |--|--|--|
# |COUNT  |       int64| Total ship count in polygone |
# |FISHING    |     int64| Amount of fishing ships in polygone |
# |PASSENGER  |     int64| Amount of Passenger ships in polygon|
# |CARGO      |     int64| Amount of Cargo ships in polygon|
# |TANKER      |    int64| Amount of Tanker ships in polygon|
# |OTHER       |    int64|Amount of Other ships in polygon|
# |SOG_mean    |  float64| |
# |COG_mean    |  float64| |
# |COG_var    |   float64| |
# |geometry   |  geometry| Geometry of the polygone  |

# %% [markdown]
# #### Create a plot MatplotLib on CartopyMap. Only the first 3000 records are plotted in this case.

# %%
CartopyMap = init_cartopymap()
CartopyMap.add_geometries(
    Exact_Earth[:3000]['geometry'], crs=ccrs.PlateCarree(), facecolor='g', edgecolor='red', alpha=0.8)

# %% [markdown]
# #### Create a plot MatplotLib on CartopyMap. Only the first 3 records are plotted in this case.

# %%
CartopyMap = init_cartopymap()
CartopyMap.add_geometries(
    Exact_Earth[:3]['geometry'], crs=ccrs.PlateCarree(), facecolor='g', edgecolor='red', alpha=0.8)
